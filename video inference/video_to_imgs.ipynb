# %%
# AWS Rekognition to get bbox
import numpy as np
import boto3
from PIL import Image, ImageDraw, ExifTags, ImageColor, ImageFont
from matplotlib import pyplot as plt
from utils.rekognition import determine_color, draw_animal_count
import cv2
import time
import math
import os
from utils.config import *
from utils.fix_annotation import *

# %%
def save_frames(src_file, output_path, output_video, fps=cv2.CAP_PROP_FPS):
    start = time.time()
    
    cap = cv2.VideoCapture(src_file)
    frameRate = cap.get(fps) #frame rate
    print('frameRate', frameRate)
    #function to write a video
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    
    imgSize = (int(width), int(height))
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    videoWriter = cv2.VideoWriter(output_video, fourcc, frameRate, imgSize)
    
    while(cap.isOpened()):
        frameId = cap.get(1) #current frame number
        
        ret, frame = cap.read()
       
        if (ret != True):
            break
        else:
            #inference on the extracted frame
            hasFrame, imageBytes = cv2.imencode(".jpg", frame)

            if(hasFrame):
                # creating image object of array
                data = Image.fromarray(frame)
                # shrink the frame image size
                # saving a JPG file
                data.save(output_path+'{}.jpg'.format(int(frameId)))
                
            if frameId % 50 == 0:
                print("Finish Processing {} frames".format(int(frameId)))
                lap = time.time()
                print('lap time: ', lap - start)
            videoWriter.write(frame)

    cap.release()
    videoWriter.release()
    cv2.destroyAllWindows()
    
    end = time.time()
    print('total time lapse', end - start)
#'cattle_single_1', 'cattle_multi_1'
video_name_list = ['lameness_0', 'lameness_1', 'lameness_2', 'lameness_3']
video_format = ['.mp4', '.mp4', '.mp4', '.mp4']
for v_idx, video_name in enumerate(video_name_list):
    src_video = 'video_data/input_video/'+video_name+video_format[v_idx]
    output_img_path = 'frame_img/'+video_name+'/'
    if not os.path.exists(output_img_path):
        os.makedirs(output_img_path)
    output_video = output_img_path+'ori_video.mp4'
    print(output_video)
    save_frames(src_video, output_img_path, output_video)
    print()
# Out:
# frame_img/lameness_0/ori_video.mp4
# frameRate 30.0
# Finish Processing 0 frames
# lap time:  0.11967039108276367
# Finish Processing 50 frames
# lap time:  4.428246736526489
# Finish Processing 100 frames
# lap time:  8.750598907470703
# Finish Processing 150 frames
# lap time:  14.718504667282104
# Finish Processing 200 frames
# lap time:  20.742175340652466
# Finish Processing 250 frames
# lap time:  26.76033878326416
# Finish Processing 300 frames
# lap time:  32.76990056037903
# Finish Processing 350 frames
# lap time:  38.75750970840454
# Finish Processing 400 frames
# lap time:  44.31333065032959
# Finish Processing 450 frames
# lap time:  50.25153136253357
# Finish Processing 500 frames
# lap time:  56.23611521720886
# Finish Processing 550 frames
# lap time:  62.240062952041626
# Finish Processing 600 frames
# lap time:  68.26928472518921
# Finish Processing 650 frames
# lap time:  74.31684899330139
# Finish Processing 700 frames
# lap time:  80.35586404800415
# Finish Processing 750 frames
# lap time:  86.40184760093689
# Finish Processing 800 frames
# lap time:  92.46822023391724
# Finish Processing 850 frames
# lap time:  98.53455686569214
# Finish Processing 900 frames
# lap time:  104.56548357009888
# Finish Processing 950 frames
# lap time:  110.59767866134644
# total time lapse 112.4195396900177
#
# frame_img/lameness_1/ori_video.mp4
# frameRate 30.0
# Finish Processing 0 frames
# lap time:  0.12584424018859863
# Finish Processing 50 frames
# lap time:  5.415350437164307
# Finish Processing 100 frames
# lap time:  11.64944577217102
# Finish Processing 150 frames
# lap time:  17.9182231426239
# Finish Processing 200 frames
# lap time:  24.130012035369873
# Finish Processing 250 frames
# lap time:  30.399182319641113
# Finish Processing 300 frames
# lap time:  36.751384973526
# Finish Processing 350 frames
# lap time:  43.080503940582275
# Finish Processing 400 frames
# lap time:  49.414326906204224
# Finish Processing 450 frames
# lap time:  56.007911682128906
# Finish Processing 500 frames
# lap time:  62.376588582992554
# Finish Processing 550 frames
# lap time:  68.54263949394226
# Finish Processing 600 frames
# lap time:  74.6071183681488
# Finish Processing 650 frames
# lap time:  80.69678807258606
# Finish Processing 700 frames
# lap time:  86.80770945549011
# Finish Processing 750 frames
# lap time:  92.85230612754822
# Finish Processing 800 frames
# lap time:  98.91019225120544
# Finish Processing 850 frames
# lap time:  104.90932536125183
# Finish Processing 900 frames
# lap time:  110.96726059913635
# Finish Processing 950 frames
# lap time:  117.12990140914917
# Finish Processing 1000 frames
# lap time:  123.29774332046509
# Finish Processing 1050 frames
# lap time:  129.49238467216492
# Finish Processing 1100 frames
# lap time:  135.7927849292755
# total time lapse 136.97216081619263
#
# frame_img/lameness_2/ori_video.mp4
# frameRate 30.0
# Finish Processing 0 frames
# lap time:  0.11700797080993652
# Finish Processing 50 frames
# lap time:  4.522037029266357
# Finish Processing 100 frames
# lap time:  10.292569160461426
# Finish Processing 150 frames
# lap time:  16.541259765625
# Finish Processing 200 frames
# lap time:  22.767218828201294
# Finish Processing 250 frames
# lap time:  28.9855854511261
# Finish Processing 300 frames
# lap time:  35.154419898986816
# Finish Processing 350 frames
# lap time:  41.315011739730835
# Finish Processing 400 frames
# lap time:  47.40660309791565
# Finish Processing 450 frames
# lap time:  53.73607611656189
# Finish Processing 500 frames
# lap time:  60.08822560310364
# Finish Processing 550 frames
# lap time:  66.3693687915802
# Finish Processing 600 frames
# lap time:  72.63942956924438
# Finish Processing 650 frames
# lap time:  78.87216663360596
# Finish Processing 700 frames
# lap time:  85.15863633155823
# Finish Processing 750 frames
# lap time:  91.17755484580994
# Finish Processing 800 frames
# lap time:  97.21915674209595
# Finish Processing 850 frames
# lap time:  103.30689573287964
# Finish Processing 900 frames
# lap time:  109.43692350387573
# Finish Processing 950 frames
# lap time:  115.53240060806274
# Finish Processing 1000 frames
# lap time:  121.58520102500916
# Finish Processing 1050 frames
# lap time:  127.64609956741333
# Finish Processing 1100 frames
# lap time:  133.6962022781372
# Finish Processing 1150 frames
# lap time:  139.72705960273743
# Finish Processing 1200 frames
# lap time:  145.71035051345825
# Finish Processing 1250 frames
# lap time:  151.8458535671234
# total time lapse 155.89403200149536
#
# frame_img/lameness_3/ori_video.mp4
# frameRate 30.0
# Finish Processing 0 frames
# lap time:  0.11653351783752441
# Finish Processing 50 frames
# lap time:  5.437029123306274
# Finish Processing 100 frames
# lap time:  11.880248785018921
# Finish Processing 150 frames
# lap time:  18.237032175064087
# Finish Processing 200 frames
# lap time:  24.626816272735596
# Finish Processing 250 frames
# lap time:  31.060712099075317
# Finish Processing 300 frames
# lap time:  37.473655223846436
# Finish Processing 350 frames
# lap time:  43.849448442459106
# Finish Processing 400 frames
# lap time:  50.23390316963196
# Finish Processing 450 frames
# lap time:  56.64362621307373
# Finish Processing 500 frames
# lap time:  62.97400784492493
# Finish Processing 550 frames
# lap time:  69.35972833633423
# Finish Processing 600 frames
# lap time:  75.74545478820801
# Finish Processing 650 frames
# lap time:  82.03206896781921
# Finish Processing 700 frames
# lap time:  88.36729526519775
# Finish Processing 750 frames
# lap time:  94.66968607902527
# Finish Processing 800 frames
# lap time:  100.98234105110168
# Finish Processing 850 frames
# lap time:  107.25823259353638
# Finish Processing 900 frames
# lap time:  113.3813464641571
# Finish Processing 950 frames
# lap time:  119.4751148223877
# Finish Processing 1000 frames
# lap time:  125.55487275123596
# Finish Processing 1050 frames
# lap time:  131.72517228126526
# Finish Processing 1100 frames
# lap time:  137.98494744300842
# Finish Processing 1150 frames
# lap time:  144.13695001602173
# Finish Processing 1200 frames
# lap time:  150.25293064117432
# Finish Processing 1250 frames
# lap time:  156.31812357902527
# Finish Processing 1300 frames
# lap time:  162.29278802871704
# Finish Processing 1350 frames
# lap time:  168.42340183258057
# total time lapse 171.37099766731262
